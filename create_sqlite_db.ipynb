# %%
import sqlite3
from sqlite3 import Error
import pandas as pd

# %%
def create_connection(db_file):
    """ create a database connection to a SQLite database """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
    finally:
        if conn:
            conn.close()


if __name__ == '__main__':
    create_connection(r"Resources/wine_data.sqlite")
# Out:
# 2.6.0

# %% [markdown]
# Create tables with schema in wine_dtaa_schema.sql file with DB Browser

# %%
# Create connection to wine_data.db
conn = sqlite3.connect("Resources/wine_data.db")

# %%
# Apply Binning from 10 scores to 3 groups
df_red = pd.read_csv("Resources/winequality-red.csv", delimiter=";")
# Create Classification version of target variable
df_red['quality'] = [2 if x >= 7 else 1 if x==6 else 0 for x in df_red['quality']]

df_white = pd.read_csv("Resources/winequality-white.csv", delimiter=";")
# Create Classification version of target variable
df_white['quality'] = [2 if x >= 7 else 1 if x==6 else 0 for x in df_white['quality']]

# %%
df_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_red.to_sql('winequalityRed', conn, if_exists='replace', index=True)

# %%
df_white.to_sql('winequalityWhite', conn, if_exists='replace', index=True)
# Out:
# /Users/Serena/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py:2615: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,
